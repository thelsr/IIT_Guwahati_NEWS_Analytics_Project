# %% [markdown]
# # Natural Language Processing for NEWS Articles

# %% [markdown]
# ## INDEX
# * Basic Imports
# * Data Preprocessing
# * Named Entity Recognition(NER)
# * Nouns Phrases
# * Tags
# * Sentiment
# * Saving Data

# %% [markdown]
# ### Basic Imports

# %%
import pandas as pd 
import numpy as np
import spacy
from spacy import displacy
from textblob import TextBlob
import os
import re

# %%
os.getcwd()
# Out:
# 'd:\\Programming\\Research\\news_project_iit_guwahati\\NLP'

# %%
folder_path = './Data/Data/allglobal_spider'

file_list = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

combined_df = pd.DataFrame()

for file in file_list:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df], ignore_index=True)

print(combined_df)
# Out:
#         ByClass                                        Date_Time  \
# 0      Politics          By Zhang Changyue  |  2022/12/2 0:43:14
# 1      Politics                  By Xinhua  |  2022/12/4 0:22:02
# 2      Politics              By Xu Keyue  |  2022/11/30 12:16:43
# 3      Politics  By Xinhua - Global Times  |  2022/12/1 19:09:29
# 4      Politics                 By Xinhua  |  2022/12/1 18:56:22
# ...         ...                                              ...
# 21276  Military                By Wang Qi  |  2023/3/13 19:53:10
# 21277  Military            By Liu Xuanzun  |  2023/3/14 20:13:21
# 21278  Military            By Liu Xuanzun  |  2023/3/13 20:07:50
# 21279  Military            By Liu Xuanzun  |  2023/3/19 18:29:47
# 21280   Economy              By Hu Weijia  |  2023/3/21 23:10:25
#
#                                                 Headline  \
# 0      Tokyo urged to heed rational voices on China a...
# 1           Chinese people continue to mourn Jiang Zemin
# 2      Japan warned of being 'biggest destabilizing f...
# 3           Jiang Zemin's remains transferred to Beijing
# 4      Memorial meeting for Comrade Jiang Zemin to be...
# ...                                                  ...
# 21276  Australia may 'pay expensive price' as AUKUS n...
# 21277  China expected to prepare for AUKUS nuclear su...
# 21278  China's 3rd aircraft carrier Fujian 'makes smo...
# 21279  Chinese, Cambodian warships hold unprecedented...
# 21280  Political plague drives presumption of guilt a...
#
#                                             Article_Lead  \
# 0      Japan on Thursday expressed "severe concerns" ...
# 1      For days, people throughout China are in mourn...
# 2      Considering Japan, a country with the pacifist...
# 3      The remains of Comrade Jiang Zemin were transf...
# 4      A memorial meeting for Comrade Jiang Zemin wil...
# ...                                                  ...
# 21276  Australia is "planting a time bomb" for its ow...
# 21277  The leaders of Australia, the UK and the US an...
# 21278  China's third aircraft carrier, the Fujian, ha...
# 21279  The Type 071 comprehensive landing ship of the...
# 21280  Once Pandora's box is opened, a political plag...
#
#                                                      Pic  \
# 0      https://www.globaltimes.cn/Portals/0/attachmen...
# 1      https://www.globaltimes.cn/Portals/0/attachmen...
# 2      https://www.globaltimes.cn/Portals/0/attachmen...
# 3      https://www.globaltimes.cn/Portals/0/attachmen...
# 4            https://www.globaltimes.cn/images/nopic.gif
# ...                                                  ...
# 21276  https://www.globaltimes.cn/Portals/0/attachmen...
# 21277  https://www.globaltimes.cn/Portals/0/attachmen...
# 21278  https://www.globaltimes.cn/Portals/0/attachmen...
# 21279  https://www.globaltimes.cn/Portals/0/attachmen...
# 21280  https://www.globaltimes.cn/Portals/0/attachmen...
#
#                                             Article_Body
# 0       Japan on Thursday expressed "severe concerns"...
# 1       For days, people throughout China are in mour...
# 2       Considering Japan, a country with the pacifis...
# 3       The remains of Comrade Jiang Zemin were trans...
# 4       A memorial meeting for Comrade Jiang Zemin wi...
# ...                                                  ...
# 21276   Australia is "planting a time bomb" for its o...
# 21277   The leaders of Australia, the UK and the US a...
# 21278
# 21279   The Type 071 comprehensive landing ship of th...
# 21280   TikTok CEO Shou Zi Chew is set to testify bef...
#
# [21281 rows x 6 columns]

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21281 entries, 0 to 21280
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ByClass       21281 non-null  object
#  1   Date_Time     21281 non-null  object
#  2   Headline      21281 non-null  object
#  3   Article_Lead  21281 non-null  object
#  4   Pic           21281 non-null  object
#  5   Article_Body  21281 non-null  object
# dtypes: object(6)
# memory usage: 997.7+ KB

# %%
combined_df.duplicated().sum()
# Out:
# 19397

# %%
combined_df.drop_duplicates(inplace=True)

# %%
combined_df.dropna(inplace=True)

# %%
combined_df.duplicated().sum()
# Out:
# 0

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1884 entries, 0 to 21280
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ByClass       1884 non-null   object
#  1   Date_Time     1884 non-null   object
#  2   Headline      1884 non-null   object
#  3   Article_Lead  1884 non-null   object
#  4   Pic           1884 non-null   object
#  5   Article_Body  1884 non-null   object
# dtypes: object(6)
# memory usage: 103.0+ KB

# %%
NER = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Named Entity Recognition(NER)

# %%
df = combined_df

# %%
def preprocess(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation and special characters
    text = re.sub(r'[^\w\s]', '', text)
    # Remove digits
    text = re.sub(r'\d+', '', text)
    # Tokenize
    doc = NER(text)
    # Remove stopwords and lemmatize
    tokens = [token.lemma_ for token in doc if not token.is_stop]
    # Join tokens back into text
    text = ' '.join(tokens)
    return text

# Apply preprocessing to text data
df['Article_Body'] = df['Article_Body'].apply(preprocess)

# Define function to perform NER
def get_entities(text):
    doc = NER(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities

# Apply NER to preprocessed text data
df['entities'] = df['Article_Body'].apply(get_entities)

# %%
df = pd.read_csv('processed_data_with_ner_mjs.csv')

# %%
type(df['entities'][0])
# Out:
# list

# %%
def extract_entities_by_type(entities, entity_type):
    return [ent[0] for ent in entities if ent[1] == entity_type]

entities_list = ['GPE','DATE','PERSON','NORP','FAC','ORG','LOC','PRODUCT','EVENT''WORK_OF_ART','LAW','LANGUAGE','TIME','PERCENT','MONEY','QUANTITY','ORDINAL','CARDINAL']

for entity in entities_list:
    df[f"{entity}"] = df['entities'].apply(lambda x: extract_entities_by_type(x, f"{entity}"))

# %%
df
# Out:
#         ByClass                                        Date_Time  \
# 0      Politics          By Zhang Changyue  |  2022/12/2 0:43:14
# 1      Politics                  By Xinhua  |  2022/12/4 0:22:02
# 2      Politics              By Xu Keyue  |  2022/11/30 12:16:43
# 3      Politics  By Xinhua - Global Times  |  2022/12/1 19:09:29
# 4      Politics                 By Xinhua  |  2022/12/1 18:56:22
# ...         ...                                              ...
# 21197   Economy     By GT staff reporters  |  2023/3/21 18:53:11
# 21198   Economy             By Yin Yeping  |  2023/3/21 22:04:34
# 21199   Economy           By Global Times  |  2023/3/21 22:38:24
# 21273  Military            By Liu Xuanzun  |  2023/3/20 23:21:19
# 21280   Economy              By Hu Weijia  |  2023/3/21 23:10:25
#
#                                                 Headline  \
# 0      Tokyo urged to heed rational voices on China a...
# 1           Chinese people continue to mourn Jiang Zemin
# 2      Japan warned of being 'biggest destabilizing f...
# 3           Jiang Zemin's remains transferred to Beijing
# 4      Memorial meeting for Comrade Jiang Zemin to be...
# ...                                                  ...
# 21197  International capitals likely to seek 'safe ha...
# 21198  Australian coal, timber trade with China resum...
# 21199  China's overnight funding rate soars to 2-year...
# 21273  Peacefully intended China-Cambodia joint exerc...
# 21280  Political plague drives presumption of guilt a...
#
#                                             Article_Lead  \
# 0      Japan on Thursday expressed "severe concerns" ...
# 1      For days, people throughout China are in mourn...
# 2      Considering Japan, a country with the pacifist...
# 3      The remains of Comrade Jiang Zemin were transf...
# 4      A memorial meeting for Comrade Jiang Zemin wil...
# ...                                                  ...
# 21197  The unfolding bank crisis in the US and Europe...
# 21198  Australian coal trade with China is set for a ...
# 21199  China's overnight funding rate, a measure of m...
# 21273  The Golden Dragon-2023 joint military exercise...
# 21280  Once Pandora's box is opened, a political plag...
#
#                                                      Pic  \
# 0      https://www.globaltimes.cn/Portals/0/attachmen...
# 1      https://www.globaltimes.cn/Portals/0/attachmen...
# 2      https://www.globaltimes.cn/Portals/0/attachmen...
# 3      https://www.globaltimes.cn/Portals/0/attachmen...
# 4            https://www.globaltimes.cn/images/nopic.gif
# ...                                                  ...
# 21197  https://www.globaltimes.cn/Portals/0/attachmen...
# 21198  https://www.globaltimes.cn/Portals/0/attachmen...
# 21199  https://www.globaltimes.cn/Portals/0/attachmen...
# 21273  https://www.globaltimes.cn/Portals/0/attachmen...
# 21280  https://www.globaltimes.cn/Portals/0/attachmen...
#
#                                             Article_Body  \
# 0        japan thursday express severe concern chinar...
# 1        day people china mourning leader jiang zemin...
# 2        consider japan country pacifist constitution...
# 3        remain comrade jiang zemin transfer beijing ...
# 4        memorial meeting comrade jiang zemin hold gr...
# ...                                                  ...
# 21197    unfold bank crisis europe highly controversi...
# 21198    australian coal trade china set recovery exp...
# 21199    china overnight funding rate measure market ...
# 21273    golden dragon joint military exercise china ...
# 21280    tiktok ceo shou zi chew set testify house en...
#
#                                                 entities  \
# 0      [(japan, GPE), (thursday, DATE), (chinarussia,...
# 1      [(china, GPE), (jiang zemin, PERSON), (wednesd...
# 2      [(japan, GPE), (chinese, NORP), (japanese, NOR...
# 3      [(jiang zemin, PERSON), (beijing, GPE), (shang...
# 4      [(jiang zemin hold great, PERSON), (beijing, G...
# ...                                                  ...
# 21197  [(europe, LOC), (tuesday, DATE), (asia, LOC), ...
# 21198  [(australian, NORP), (china, GPE), (february, ...
# 21199  [(china, GPE), (overnight, TIME), (february, D...
# 21273  [(china, GPE), (cambodia, GPE), (monday, DATE)...
# 21280  [(shou, GPE), (house energy commerce committee...
#
#                                                      GPE  \
# 0      [japan, chinarussia, china, japan, china, japa...
# 1      [china, shanghai, tianjin, tianjin, yanan, yan...
# 2      [japan, taiwan, japan, japan, united states, j...
# 3      [beijing, shanghai, jiang, shanghai, jiang, sh...
# 4                                              [beijing]
# ...                                                  ...
# 21197  [hong kong, singapore, singapore, switzerland,...
# 21198      [china, australia, china, china, china, hong]
# 21199                              [china, china, china]
# 21273  [china, cambodia, cambodia, cambodia, china, c...
# 21280  [shou, washington, china, china, china, china,...
#
#                                                     DATE  \
# 0      [thursday, thursday, early month, thursday, ye...
# 1                      [wednesday, past   year, january]
# 2      [monday, tuesday, year, year, recent year, tue...
# 3      [thursday, wednesday, december, december, wedn...
# 4                                             [thursday]
# ...                                                  ...
# 21197  [tuesday, tuesday, friday, tuesday, monday, mo...
# 21198  [february, half year, month, february, monday,...
# 21199             [february, february, february, friday]
# 21273    [monday, sunday, monday, april, monday, monday]
# 21280  [thursday, recent week, recent year, thursday,...
#
#                                                   PERSON  ... PRODUCT  \
# 0                                                 [chao]  ...      []
# 1      [jiang zemin, jiang deathwang, jiang zemin, fe...  ...      []
# 2      [yasukazu hamada, meetingjapan long cap, joe b...  ...      []
# 3      [jiang zemin, li keqiang li zhanshu wang yang ...  ...      []
# 4                 [jiang zemin hold great, jiang zemins]  ...      []
# ...                                                  ...  ...     ...
# 21197                                                 []  ...      []
# 21198                                         [ton coke]  ...      []
# 21199       [zhou maohua, zhou saidchina, zhou saidzhou]  ...      []
# 21273                   [chen xiangmiao, warplanes chen]  ...      []
# 21280                                                 []  ...      []
#
#       EVENTWORK_OF_ART LAW LANGUAGE                     TIME PERCENT  \
# 0                   []  []       []                       []      []
# 1                   []  []       []  [age minute, kilometer]      []
# 2                   []  []       []                       []      []
# 3                   []  []       []          [noon, morning]      []
# 4                   []  []       []                       []      []
# ...                ...  ..      ...                      ...     ...
# 21197               []  []       []                       []      []
# 21198               []  []       []                       []      []
# 21199               []  []       []              [overnight]      []
# 21273               []  []       []                       []      []
# 21280               []  []       []                [morning]      []
#
#                               MONEY       QUANTITY   ORDINAL   CARDINAL
# 0                                []             []  [second]         []
# 1                                []             []        []         []
# 2      [trillion yen, trillion yen]             []        []         []
# 3                                []             []        []     [half]
# 4                                []             []        []         []
# ...                             ...            ...       ...        ...
# 21197         [billion swiss franc]             []        []  [billion]
# 21198                            []  [million ton]        []         []
# 21199                [billion yuan]             []        []         []
# 21273                            []             []   [fifth]         []
# 21280                            []             []        []      [one]
#
# [1884 rows x 24 columns]

# %%
df.to_csv('processed_data_with_ner_mjs.csv', index=False)

# %% [markdown]
# ### Noun Phrases

# %%
df["Noun Phrases"] = df["Article_Body"].apply(lambda x : TextBlob(str(x)).noun_phrases)

# %% [markdown]
# ### Tags

# %%
df["Tags"] = df["Article_Body"].apply(lambda x : TextBlob(str(x)).tags)

# %% [markdown]
# ### Sentiment

# %%
df["Sentiment"] = df["Article_Body"].apply(lambda x : TextBlob(str(x)).sentiment)

# %% [markdown]
# ### Saving Data

# %%
data.head()
# Out:
#                                              ByClass          DateTime  \
# 0              \t\t\t\tarmed forces   armynews\t\t\t  2020-10-28 10:22
# 1              \t\t\t\tarmed forces   armynews\t\t\t  2020-11-18 19:24
# 2              \t\t\t\tarmed forces   armynews\t\t\t  2021-01-14 17:13
# 3  \t\t\t\tarmed forces   armed police forcenews\...  2020-04-27 08:31
# 4              \t\t\t\tarmed forces   armynews\t\t\t  2021-06-08 11:37
#
#                                             Headline  \
# 0  \t\t\t\t\t\tpla army debuts occupational quali...
# 1  \t\t\t\t\t\tarmy aviation brigade uses drones ...
# 2  \t\t\t\t\t\tmilitary academy trains border def...
# 3  \t\t\t\t\t\tchinas top legislature reviews dra...
# 4  \t\t\t\t\t\tpla army academies release promoti...
#
#                                         Article_Lead                 Date  \
# 0  recently the pla army launched its first occup...  2020-10-28 10:22:27
# 1  a drone was used to guide a helicopter to cond...  2020-11-18 19:24:55
# 2  a total of 30 grassroots cadres and police off...  2021-01-14 17:13:40
# 3  china on sunday drafted an amendment to the la...  2020-04-27 08:31:30
# 4  recently the peoples liberation army pla relea...  2021-06-08 11:37:32
#
#                                         Article_Body  \
# 0  by li hao and han chengbeijing oct 28  recentl...
# 1  by gao junfeng and xiang xubeijing nov 18  a d...
# 2  by li qinghua and song peng urumqi jan 14  a t...
# 3  china on sunday drafted an amendment to the la...
# 4  recently the peoples liberation army pla relea...
#
#                                                  NER  \
# 0  (by, li, hao, and, han, chengbeijing, oct, 28,...
# 1  (by, gao, junfeng, and, xiang, xubeijing, nov,...
# 2  (by, li, qinghua, and, song, peng, urumqi, jan...
# 3  (china, on, sunday, drafted, an, amendment, to...
# 4  (recently, the, peoples, liberation, army, pla...
#
#                                         Noun Phrases  \
# 0  [li hao, pla army plaa, occupational qualifica...
# 1  [gao junfeng, visual range bvr strike, livefir...
# 2  [li qinghua, song peng urumqi jan, grassroots ...
# 3  [police force, such things, emergency situatio...
# 4  [peoples liberation army pla, promotional vide...
#
#                                                 Tags  \
# 0  [(by, IN), (li, JJ), (hao, NN), (and, CC), (ha...
# 1  [(by, IN), (gao, JJ), (junfeng, NN), (and, CC)...
# 2  [(by, IN), (li, JJ), (qinghua, NN), (and, CC),...
# 3  [(china, NN), (on, IN), (sunday, NN), (drafted...
# 4  [(recently, RB), (the, DT), (peoples, NNS), (l...
#
#                                        Sentiment
# 0     (0.14375000000000002, 0.30069444444444443)
# 1  (-0.0021052631578947242, 0.44859649122807016)
# 2     (0.14074074074074075, 0.46481481481481485)
# 3      (0.0821127946127946, 0.28404882154882155)
# 4     (0.04666666666666665, 0.23666666666666666)

# %%
data.to_csv("processed_file_with_ner.csv")
